# %%
#content of the files
with open('data/data/typeofheartbeats/101', 'r') as file:
    lines101 = file.readlines() 
with open("data/data/subconjuntos/archivoslab/101.lab", 'w+') as output_file:
    output_file.write('"*/101.lab"')
    output_file.write("\n")
    for line in lines101:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
        
with open('data/data/typeofheartbeats/102', 'r') as file:
    lines102 = file.readlines() 
with open("data/data/subconjuntos/archivoslab/102.lab", 'w+') as output_file:
    output_file.write('"*/102.lab"')
    output_file.write("\n")
    for line in lines102:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")    
    
with open('data/data/typeofheartbeats/106', 'r') as file:
    lines106 = file.readlines()
with open("data/data/subconjuntos/archivoslab/106.lab", 'w+') as output_file:
    output_file.write('"*/106.lab"')
    output_file.write("\n")
    for line in lines106:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/108', 'r') as file:
    lines108 = file.readlines()  
with open("data/data/subconjuntos/archivoslab/108.lab", 'w+') as output_file:
    output_file.write('"*/108.lab"')
    output_file.write("\n")
    for line in lines108:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")   
    
with open('data/data/typeofheartbeats/109', 'r') as file:
    lines109 = file.readlines()  
with open("data/data/subconjuntos/archivoslab/109.lab", 'w+') as output_file:
    output_file.write('"*/109.lab"')
    output_file.write("\n")
    for line in lines109:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")   
    
with open('data/data/typeofheartbeats/112', 'r') as file:
    lines112 = file.readlines() 
with open("data/data/subconjuntos/archivoslab/112.lab", 'w+') as output_file:
    output_file.write('"*/112.lab"')
    output_file.write("\n")
    for line in lines112:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/114', 'r') as file:
    lines114 = file.readlines() 
with open("data/data/subconjuntos/archivoslab/114.lab", 'w+') as output_file:
    output_file.write('"*/114.lab"')
    output_file.write("\n")
    for line in lines114:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/115', 'r') as file:
    lines115 = file.readlines()   
with open("data/data/subconjuntos/archivoslab/115.lab", 'w+') as output_file:
    output_file.write('"*/115.lab"')
    output_file.write("\n")
    for line in lines115:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/116', 'r') as file:
    lines116 = file.readlines() 
with open("data/data/subconjuntos/archivoslab/116.lab", 'w+') as output_file:
    output_file.write('"*/116.lab"')
    output_file.write("\n")
    for line in lines116:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/118', 'r') as file:
    lines118 = file.readlines()
with open("data/data/subconjuntos/archivoslab/118.lab", 'w+') as output_file:
    output_file.write('"*/118.lab"')
    output_file.write("\n")
    for line in lines118:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/119', 'r') as file:
    lines119 = file.readlines()    
with open("data/data/subconjuntos/archivoslab/119.lab", 'w+') as output_file:
    output_file.write('"*/119.lab"')
    output_file.write("\n")
    for line in lines119:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/122', 'r') as file:
    lines122 = file.readlines()
with open("data/data/subconjuntos/archivoslab/122.lab", 'w+') as output_file:
    output_file.write('"*/122.lab"')
    output_file.write("\n")
    for line in lines122:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/124', 'r') as file:
    lines124 = file.readlines()
with open("data/data/subconjuntos/archivoslab/124.lab", 'w+') as output_file:
    output_file.write('"*/124.lab"')
    output_file.write("\n")
    for line in lines124:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/201', 'r') as file:
    lines201 = file.readlines()
with open("data/data/subconjuntos/archivoslab/201.lab", 'w+') as output_file:
    output_file.write('"*/201.lab"')
    output_file.write("\n")
    for line in lines201:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/203', 'r') as file:
    lines203 = file.readlines()
with open("data/data/subconjuntos/archivoslab/203.lab", 'w+') as output_file:
    output_file.write('"*/203.lab"')
    output_file.write("\n")
    for line in lines203:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/205', 'r') as file:
    lines205 = file.readlines()
with open("data/data/subconjuntos/archivoslab/205.lab", 'w+') as output_file:
    output_file.write('"*/205.lab"')
    output_file.write("\n")
    for line in lines205:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/207', 'r') as file:
    lines207 = file.readlines()
with open("data/data/subconjuntos/archivoslab/207.lab", 'w+') as output_file:
    output_file.write('"*/207.lab"')
    output_file.write("\n")
    for line in lines207:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/208', 'r') as file:
    lines208 = file.readlines()
with open("data/data/subconjuntos/archivoslab/208.lab", 'w+') as output_file:
    output_file.write('"*/208.lab"')
    output_file.write("\n")
    for line in lines208:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
    
with open('data/data/typeofheartbeats/209', 'r') as file:
    lines209 = file.readlines()
with open("data/data/subconjuntos/archivoslab/209.lab", 'w+') as output_file:
    output_file.write('"*/209.lab"')
    output_file.write("\n")
    for line in lines209:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/215', 'r') as file:
    lines215 = file.readlines()
with open("data/data/subconjuntos/archivoslab/215.lab", 'w+') as output_file:
    output_file.write('"*/215.lab"')
    output_file.write("\n")
    for line in lines215:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/217', 'r') as file:
    lines217 = file.readlines()
with open("data/data/subconjuntos/archivoslab/217.lab", 'w+') as output_file:
    output_file.write('"*/217.lab"')
    output_file.write("\n")
    for line in lines217:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
    
with open('data/data/typeofheartbeats/220', 'r') as file:
    lines220 = file.readlines()
with open("data/data/subconjuntos/archivoslab/220.lab", 'w+') as output_file:
    output_file.write('"*/220.lab"')
    output_file.write("\n")
    for line in lines220:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
    
with open('data/data/typeofheartbeats/223', 'r') as file:
    lines223 = file.readlines()
with open("data/data/subconjuntos/archivoslab/223.lab", 'w+') as output_file:
    output_file.write('"*/223.lab"')
    output_file.write("\n")
    for line in lines223:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    
with open('data/data/typeofheartbeats/230', 'r') as file:
    lines230 = file.readlines()
with open("data/data/subconjuntos/archivoslab/230.lab", 'w+') as output_file:
    output_file.write('"*/230.lab"')
    output_file.write("\n")
    for line in lines230:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")

# %%
         
#Subgroup 1
#files used for training: 102, 108, 109, 112, 114, 115, 116, 118, 119, 122, 124, 
#201, 203, 207, 208, 209, 215, 217, 220, 223, 230    
outputfilepathsubconjunto1 = "data/data/subconjuntos/groundtruth1.txt"
with open(outputfilepathsubconjunto1, 'w+') as output_file:
    output_file.write("#!MLF!#") #header
    output_file.write("\n")
    output_file.write('"*/102.lab"')
    output_file.write("\n")
    for line in lines102:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/108.lab"')
    output_file.write("\n")
    for line in lines108:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/109.lab"')
    output_file.write("\n")
    for line in lines109:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/112.lab"')
    output_file.write("\n")
    for line in lines112:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/114.lab"')
    output_file.write("\n")
    for line in lines114:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/115.lab"')
    output_file.write("\n")
    for line in lines115:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/116.lab"')
    output_file.write("\n")
    for line in lines116:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/118.lab"')
    output_file.write("\n")
    for line in lines118:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/119.lab"')
    output_file.write("\n")
    for line in lines119:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/122.lab"')
    output_file.write("\n")
    for line in lines122:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/124.lab"')
    output_file.write("\n")
    for line in lines124:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/201.lab"')
    output_file.write("\n")
    for line in lines201:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/203.lab"')
    output_file.write("\n")
    for line in lines203:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/207.lab"')
    output_file.write("\n")
    for line in lines207:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/208.lab"')
    output_file.write("\n")
    for line in lines208:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/209.lab"')
    output_file.write("\n")
    for line in lines209:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/215.lab"')
    output_file.write("\n")
    for line in lines215:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/217.lab"')
    output_file.write("\n")
    for line in lines217:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/220.lab"')
    output_file.write("\n")
    for line in lines220:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/223.lab"')
    output_file.write("\n")
    for line in lines223:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/230.lab"')
    output_file.write("\n")
    for line in lines230:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")

# %%
#Subgroup 2 
#files used for training: 101, 102, 106, 108, 109, 112, 114, 115, 116, 118, 122,
#201, 203, 205, 207, 209, 215, 217, 220, 223, 230
outputfilepathsubconjunto1 = "data/data/subconjuntos/groundtruth2.txt"
          #ENCABEZADO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
with open(outputfilepathsubconjunto1, 'w+') as output_file:
    output_file.write("#!MLF!#") #header
    output_file.write("\n")
    output_file.write('"*/101.lab"')
    output_file.write("\n")
    for line in lines101:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/102.lab"')
    output_file.write("\n")
    for line in lines102:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/106.lab"')
    output_file.write("\n")
    for line in lines106:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/108.lab"')
    output_file.write("\n")
    for line in lines108:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/109.lab"')
    output_file.write("\n")
    for line in lines109:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/112.lab"')
    output_file.write("\n")
    for line in lines112:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/114.lab"')
    output_file.write("\n")
    for line in lines114:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/115.lab"')
    output_file.write("\n")
    for line in lines115:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/116.lab"')
    output_file.write("\n")
    for line in lines116:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/118.lab"')
    output_file.write("\n")
    for line in lines118:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/122.lab"')
    output_file.write("\n")
    for line in lines122:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/201.lab"')
    output_file.write("\n")
    for line in lines201:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/203.lab"')
    output_file.write("\n")
    for line in lines203:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/205.lab"')
    output_file.write("\n")
    for line in lines205:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/207.lab"')
    output_file.write("\n")
    for line in lines207:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/209.lab"')
    output_file.write("\n")
    for line in lines209:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/215.lab"')
    output_file.write("\n")
    for line in lines215:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/217.lab"')
    output_file.write("\n")
    for line in lines217:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/220.lab"')
    output_file.write("\n")
    for line in lines220:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/223.lab"')
    output_file.write("\n")
    for line in lines223:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/230.lab"')
    output_file.write("\n")
    for line in lines230:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")

# %%
#Subgroup 3 
#files used for training: 101, 102, 106, 108,109, 112, 114, 115, 116, 118, 119, 122, 124,
#201, 205, 208,  215, 217, 220, 223, 230
outputfilepathsubconjunto1 = "data/data/subconjuntos/groundtruth3.txt"
          #ENCABEZADO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
with open(outputfilepathsubconjunto1, 'w+') as output_file:
    output_file.write("#!MLF!#") #header
    output_file.write("\n")
    output_file.write('"*/101.lab"')
    output_file.write("\n")
    for line in lines101:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/102.lab"')
    output_file.write("\n")
    for line in lines102:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/106.lab"')
    output_file.write("\n")
    for line in lines106:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/108.lab"')
    output_file.write("\n")
    for line in lines108:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/109.lab"')
    output_file.write("\n")
    for line in lines109:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/112.lab"')
    output_file.write("\n")
    for line in lines112:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/114.lab"')
    output_file.write("\n")
    for line in lines114:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/115.lab"')
    output_file.write("\n")
    for line in lines115:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/116.lab"')
    output_file.write("\n")
    for line in lines116:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/118.lab"')
    output_file.write("\n")
    for line in lines118:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/119.lab"')
    output_file.write("\n")
    for line in lines119:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/122.lab"')
    output_file.write("\n")
    for line in lines122:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/124.lab"')
    output_file.write("\n")
    for line in lines124:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/201.lab"')
    output_file.write("\n")
    for line in lines201:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/205.lab"')
    output_file.write("\n")
    for line in lines205:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/208.lab"')
    output_file.write("\n")
    for line in lines208:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/215.lab"')
    output_file.write("\n")
    for line in lines215:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/217.lab"')
    output_file.write("\n")
    for line in lines217:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/220.lab"')
    output_file.write("\n")
    for line in lines220:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/223.lab"')
    output_file.write("\n")
    for line in lines223:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/230.lab"')
    output_file.write("\n")
    for line in lines230:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")

# %%
#Subgroup 4
#files used for training: 101, 102, 106, 108, 109, 112, 114, 116, 118, 119, 122, 124
#201, 203, 205, 207, 208, 209, 215, 220, 230
outputfilepathsubconjunto1 = "data/data/subconjuntos/groundtruth4.txt"
          #ENCABEZADO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
with open(outputfilepathsubconjunto1, 'w+') as output_file:
    output_file.write("#!MLF!#") #header
    output_file.write("\n")
    output_file.write('"*/101.lab"')
    output_file.write("\n")
    for line in lines101:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/102.lab"')
    output_file.write("\n")
    for line in lines102:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/106.lab"')
    output_file.write("\n")
    for line in lines106:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/108.lab"')
    output_file.write("\n")
    for line in lines108:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/109.lab"')
    output_file.write("\n")
    for line in lines109:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/112.lab"')
    output_file.write("\n")
    for line in lines112:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/114.lab"')
    output_file.write("\n")
    for line in lines114:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/116.lab"')
    output_file.write("\n")
    for line in lines116:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/118.lab"')
    output_file.write("\n")
    for line in lines118:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/119.lab"')
    output_file.write("\n")
    for line in lines119:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/122.lab"')
    output_file.write("\n")
    for line in lines122:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/124.lab"')
    output_file.write("\n")
    for line in lines124:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/201.lab"')
    output_file.write("\n")
    for line in lines201:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/203.lab"')
    output_file.write("\n")
    for line in lines203:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/205.lab"')
    output_file.write("\n")
    for line in lines205:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/207.lab"')
    output_file.write("\n")
    for line in lines207:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/208.lab"')
    output_file.write("\n")
    for line in lines208:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/209.lab"')
    output_file.write("\n")
    for line in lines209:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/215.lab"')
    output_file.write("\n")
    for line in lines215:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/220.lab"')
    output_file.write("\n")
    for line in lines220:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/230.lab"')
    output_file.write("\n")
    for line in lines230:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")

# %%
#Subgroup 5
#files used for training: 101, 106, 108, 109, 112, 114, 115, 116, 118, 119, 122, 124
#203, 205, 207, 208, 209, 215, 217, 220, 223, 
outputfilepathsubconjunto1 = "data/data/subconjuntos/groundtruth5.txt"
          #ENCABEZADO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
with open(outputfilepathsubconjunto1, 'w+') as output_file:
    output_file.write("#!MLF!#") #header
    output_file.write("\n")
    output_file.write('"*/101.lab"')
    output_file.write("\n")
    for line in lines101:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/106.lab"')
    output_file.write("\n")
    for line in lines106:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/108.lab"')
    output_file.write("\n")
    for line in lines108:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/109.lab"')
    output_file.write("\n")
    for line in lines109:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/112.lab"')
    output_file.write("\n")
    for line in lines112:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/114.lab"')
    output_file.write("\n")
    for line in lines114:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/115.lab"')
    output_file.write("\n")
    for line in lines115:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/116.lab"')
    output_file.write("\n")
    for line in lines116:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/118.lab"')
    output_file.write("\n")
    for line in lines118:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/119.lab"')
    output_file.write("\n")
    for line in lines119:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/122.lab"')
    output_file.write("\n")
    for line in lines122:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/124.lab"')
    output_file.write("\n")
    for line in lines124:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/203.lab"')
    output_file.write("\n")
    for line in lines203:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/205.lab"')
    output_file.write("\n")
    for line in lines205:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/207.lab"')
    output_file.write("\n")
    for line in lines207:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/208.lab"')
    output_file.write("\n")
    for line in lines208:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/209.lab"')
    output_file.write("\n")
    for line in lines209:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/215.lab"')
    output_file.write("\n")
    for line in lines215:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/217.lab"')
    output_file.write("\n")
    for line in lines217:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/220.lab"')
    output_file.write("\n")
    for line in lines220:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/223.lab"')
    output_file.write("\n")
    for line in lines223:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")

# %%
#Subgroup 6
#files used for training: 101, 102, 106, 109, 112, 114, 115, 118, 119, 124
#201, 203, 205, 207, 208, 209, 215, 217, 220, 223, 230
outputfilepathsubconjunto1 = "data/data/subconjuntos/groundtruth6.txt"
          #ENCABEZADO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
with open(outputfilepathsubconjunto1, 'w+') as output_file:
    output_file.write("#!MLF!#") #header
    output_file.write("\n")
    output_file.write('"*/101.lab"')
    output_file.write("\n")
    for line in lines101:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/102.lab"')
    output_file.write("\n")
    for line in lines102:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/106.lab"')
    output_file.write("\n")
    for line in lines106:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/109.lab"')
    output_file.write("\n")
    for line in lines109:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/112.lab"')
    output_file.write("\n")
    for line in lines112:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/114.lab"')
    output_file.write("\n")
    for line in lines114:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/115.lab"')
    output_file.write("\n")
    for line in lines115:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/118.lab"')
    output_file.write("\n")
    for line in lines118:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/119.lab"')
    output_file.write("\n")
    for line in lines119:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/124.lab"')
    output_file.write("\n")
    for line in lines124:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/201.lab"')
    output_file.write("\n")
    for line in lines201:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/203.lab"')
    output_file.write("\n")
    for line in lines203:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/205.lab"')
    output_file.write("\n")
    for line in lines205:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/207.lab"')
    output_file.write("\n")
    for line in lines207:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/208.lab"')
    output_file.write("\n")
    for line in lines208:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/209.lab"')
    output_file.write("\n")
    for line in lines209:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/215.lab"')
    output_file.write("\n")
    for line in lines215:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/217.lab"')
    output_file.write("\n")
    for line in lines217:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/220.lab"')
    output_file.write("\n")
    for line in lines220:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/223.lab"')
    output_file.write("\n")
    for line in lines223:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/230.lab"')
    output_file.write("\n")
    for line in lines230:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")

# %%
#Subgroup 7
#files used for training: 101, 102, 106, 108, 109, 115, 116, 118, 119, 122, 124
#201, 203, 205, 207, 208, 209, 217, 220, 223, 230
outputfilepathsubconjunto1 = "data/data/subconjuntos/groundtruth7.txt"
          #ENCABEZADO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
with open(outputfilepathsubconjunto1, 'w+') as output_file:
    output_file.write("#!MLF!#") #header
    output_file.write("\n")
    output_file.write('"*/101.lab"')
    output_file.write("\n")
    for line in lines101:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/102.lab"')
    output_file.write("\n")
    for line in lines102:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/106.lab"')
    output_file.write("\n")
    for line in lines106:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/108.lab"')
    output_file.write("\n")
    for line in lines108:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/109.lab"')
    output_file.write("\n")
    for line in lines109:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/115.lab"')
    output_file.write("\n")
    for line in lines115:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/116.lab"')
    output_file.write("\n")
    for line in lines116:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/118.lab"')
    output_file.write("\n")
    for line in lines118:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/119.lab"')
    output_file.write("\n")
    for line in lines119:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/122.lab"')
    output_file.write("\n")
    for line in lines122:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/124.lab"')
    output_file.write("\n")
    for line in lines124:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/201.lab"')
    output_file.write("\n")
    for line in lines201:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/203.lab"')
    output_file.write("\n")
    for line in lines203:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/205.lab"')
    output_file.write("\n")
    for line in lines205:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/207.lab"')
    output_file.write("\n")
    for line in lines207:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/208.lab"')
    output_file.write("\n")
    for line in lines208:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/209.lab"')
    output_file.write("\n")
    for line in lines209:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/217.lab"')
    output_file.write("\n")
    for line in lines217:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/220.lab"')
    output_file.write("\n")
    for line in lines220:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/223.lab"')
    output_file.write("\n")
    for line in lines223:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/230.lab"')
    output_file.write("\n")
    for line in lines230:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")

# %%
#Subgroup 8
#files used for training: 101, 102, 106, 108,  112, 114, 115, 116, 119, 122, 124
#201, 203, 205, 207, 208, 209, 215, 217, 223, 230
outputfilepathsubconjunto1 = "data/data/subconjuntos/groundtruth8.txt"
          #ENCABEZADO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
with open(outputfilepathsubconjunto1, 'w+') as output_file:
    output_file.write("#!MLF!#") #header
    output_file.write("\n")
    output_file.write('"*/101.lab"')
    output_file.write("\n")
    for line in lines101:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/102.lab"')
    output_file.write("\n")
    for line in lines102:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/106.lab"')
    output_file.write("\n")
    for line in lines106:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/108.lab"')
    output_file.write("\n")
    for line in lines108:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/112.lab"')
    output_file.write("\n")
    for line in lines112:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/114.lab"')
    output_file.write("\n")
    for line in lines114:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/115.lab"')
    output_file.write("\n")
    for line in lines115:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/116.lab"')
    output_file.write("\n")
    for line in lines116:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/119.lab"')
    output_file.write("\n")
    for line in lines119:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/122.lab"')
    output_file.write("\n")
    for line in lines122:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/124.lab"')
    output_file.write("\n")
    for line in lines124:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/201.lab"')
    output_file.write("\n")
    for line in lines201:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/203.lab"')
    output_file.write("\n")
    for line in lines203:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/205.lab"')
    output_file.write("\n")
    for line in lines205:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/207.lab"')
    output_file.write("\n")
    for line in lines207:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/208.lab"')
    output_file.write("\n")
    for line in lines208:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/209.lab"')
    output_file.write("\n")
    for line in lines209:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/215.lab"')
    output_file.write("\n")
    for line in lines215:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/217.lab"')
    output_file.write("\n")
    for line in lines217:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/223.lab"')
    output_file.write("\n")
    for line in lines223:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
    output_file.write('"*/230.lab"')
    output_file.write("\n")
    for line in lines230:  
        output_file.write(line)
    output_file.write(".")
    output_file.write("\n")
